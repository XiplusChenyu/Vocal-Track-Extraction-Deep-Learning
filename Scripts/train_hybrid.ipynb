# %%
from hybrid_model import H_model
from hd_train import main_train
from config import PARAS
from data_loader import torch_dataset_loader

# %%
train_file = 'train_enhanced.h5'
valid_file = 'valid_enhanced.h5'
train_loader = torch_dataset_loader(PARAS.DATASET_PATH + train_file, PARAS.BATCH_SIZE, True, PARAS.kwargs)
valid_loader = torch_dataset_loader(PARAS.DATASET_PATH + valid_file, PARAS.BATCH_SIZE, False, PARAS.kwargs)

# %%
res = main_train(model=H_model,
                 train_loader=train_loader,
                 valid_loader=valid_loader,
                 log_name='hd_model_newset_may_11.json',
                 save_name='hd_model_newset_may_11.pt')
# Out:
# Epoch  1 | 313/1254 batches | 608.34ms/ batch | LOSS_DC: 1.3874 | LOSS_MASK: 0.6111 |
# Epoch  1 | 626/1254 batches | 607.79ms/ batch | LOSS_DC: 1.3400 | LOSS_MASK: 0.5919 |
# Epoch  1 | 939/1254 batches | 605.64ms/ batch | LOSS_DC: 1.3059 | LOSS_MASK: 0.5795 |
# Epoch  1 | 1252/1254 batches | 606.12ms/ batch | LOSS_DC: 1.2822 | LOSS_MASK: 0.5714 |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   1 | time: 760.06s |  LOSS_DC: 1.2820 | LOSS_MASK: 0.5714 |
# End of validation epoch   1 | time: 19.46s | LOSS_DC: 1.1841 | LOSS_MASK: 0.5278
# ---------------------------------------------------------------------------------------------------
# ****Save 1 Epoch in ../Log/hd_model_newset_may_11.json****
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# ...

# %%
res = main_train(model=H_model,
                 train_loader=train_loader,
                 valid_loader=valid_loader,
                 log_name='hd_model_newset_may_11_after50.json',
                 save_name='hd_model_newset_may_11_after50.pt')
# Out:
# Epoch  1 | 313/1254 batches | 607.24ms/ batch | LOSS_DC: 0.8392 | LOSS_MASK: 0.4052 |
# Epoch  1 | 626/1254 batches | 603.60ms/ batch | LOSS_DC: 0.8332 | LOSS_MASK: 0.4024 |
# Epoch  1 | 939/1254 batches | 604.31ms/ batch | LOSS_DC: 0.8321 | LOSS_MASK: 0.4014 |
# Epoch  1 | 1252/1254 batches | 603.82ms/ batch | LOSS_DC: 0.8299 | LOSS_MASK: 0.4004 |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   1 | time: 757.15s |  LOSS_DC: 0.8298 | LOSS_MASK: 0.4004 |
# End of validation epoch   1 | time: 18.67s | LOSS_DC: 0.8552 | LOSS_MASK: 0.3987
# ---------------------------------------------------------------------------------------------------
# ****Save 1 Epoch in ../Log/hd_model_newset_may_11_after50.json****
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# ...

# %%
res = main_train(model=H_model,
                 train_loader=train_loader,
                 valid_loader=valid_loader,
                 log_name='hd_model_newset_may_11_after100.json',
                 save_name='hd_model_newset_may_11_after100.pt')
# Out:
# Epoch  1 | 313/1254 batches | 283.00ms/ batch | LOSS_DC: 0.7619 | LOSS_MASK: 0.3765 |
# Epoch  1 | 626/1254 batches | 282.65ms/ batch | LOSS_DC: 0.7548 | LOSS_MASK: 0.3742 |
# Epoch  1 | 939/1254 batches | 282.80ms/ batch | LOSS_DC: 0.7536 | LOSS_MASK: 0.3743 |
# Epoch  1 | 1252/1254 batches | 282.69ms/ batch | LOSS_DC: 0.7536 | LOSS_MASK: 0.3742 |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   1 | time: 354.52s |  LOSS_DC: 0.7536 | LOSS_MASK: 0.3742 |
# End of validation epoch   1 | time:  8.55s | LOSS_DC: 0.8204 | LOSS_MASK: 0.3813
# ---------------------------------------------------------------------------------------------------
# ****Save 1 Epoch in ../Log/hd_model_newset_may_11_after100.json****
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# ...
