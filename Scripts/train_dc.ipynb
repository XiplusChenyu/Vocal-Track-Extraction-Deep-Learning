# %%
from cluster_model import D_model
from dc_train import main_train
from config import PARAS
from data_loader import torch_dataset_loader

train_file = 'train_enhanced.h5'
valid_file = 'valid_enhanced.h5'
train_loader = torch_dataset_loader(PARAS.DATASET_PATH + train_file, PARAS.BATCH_SIZE, True, PARAS.kwargs)
valid_loader = torch_dataset_loader(PARAS.DATASET_PATH + valid_file, PARAS.BATCH_SIZE, False, PARAS.kwargs)

# %%
res = main_train(model=D_model,
                 train_loader=train_loader,
                 valid_loader=valid_loader,
                 log_name='dc_model_may_new_set_May11.json',
                 save_name='dc_model_may_new_set_May11.pt')
# Out:
# Epoch  1 | 313/1254 batches | 325.46ms/ batch | LOSS: 1.4056 |
# Epoch  1 | 626/1254 batches | 350.87ms/ batch | LOSS: 1.3495 |
# Epoch  1 | 939/1254 batches | 359.41ms/ batch | LOSS: 1.3226 |
# Epoch  1 | 1252/1254 batches | 363.54ms/ batch | LOSS: 1.3022 |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   1 | time: 455.92s | LOSS: 1.3019 |
# End of validation epoch   1 | time: 18.62s | LOSS: 1.2317 |
# ---------------------------------------------------------------------------------------------------
# ****Save 1 Epoch in ../Log/dc_model_may_new_set_May11.json****
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  2 | 313/1254 batches | 376.40ms/ batch | LOSS: 1.2369 |
# Epoch  2 | 626/1254 batches | 376.03ms/ batch | LOSS: 1.2285 |
# ...

# %%
res = main_train(model=D_model,
                 train_loader=train_loader,
                 valid_loader=valid_loader,
                 log_name='dc_model_may_new_set_May11_after50.json',
                 save_name='dc_model_may_new_set_May11_after50.pt')
# Out:
# Epoch  1 | 313/1254 batches | 374.48ms/ batch | LOSS: 0.9156 |
# Epoch  1 | 626/1254 batches | 371.22ms/ batch | LOSS: 0.9103 |
# Epoch  1 | 939/1254 batches | 372.62ms/ batch | LOSS: 0.9077 |
# Epoch  1 | 1252/1254 batches | 373.15ms/ batch | LOSS: 0.9071 |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   1 | time: 467.96s | LOSS: 0.9069 |
# End of validation epoch   1 | time: 18.79s | LOSS: 0.9275 |
# ---------------------------------------------------------------------------------------------------
# ****Save 1 Epoch in ../Log/dc_model_may_new_set_May11_after50.json****
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  2 | 313/1254 batches | 375.85ms/ batch | LOSS: 0.9034 |
# Epoch  2 | 626/1254 batches | 375.66ms/ batch | LOSS: 0.9029 |
# ...

# %%
res = main_train(model=D_model,
                 train_loader=train_loader,
                 valid_loader=valid_loader,
                 log_name='dc_model_may_new_set_May11_after100.json',
                 save_name='dc_model_may_new_set_May11_after100.pt')
# Out:
# Epoch  1 | 313/1254 batches | 376.37ms/ batch | LOSS: 0.8332 |
# Epoch  1 | 939/1254 batches | 376.03ms/ batch | LOSS: 0.8279 |
# Epoch  1 | 1252/1254 batches | 375.76ms/ batch | LOSS: 0.8294 |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   1 | time: 471.20s | LOSS: 0.8295 |
# End of validation epoch   1 | time: 18.71s | LOSS: 0.8736 |
# ---------------------------------------------------------------------------------------------------
# ****Save 1 Epoch in ../Log/dc_model_may_new_set_May11_after100.json****
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  2 | 313/1254 batches | 376.41ms/ batch | LOSS: 0.8272 |
# Epoch  2 | 626/1254 batches | 373.65ms/ batch | LOSS: 0.8252 |
# Epoch  2 | 939/1254 batches | 374.25ms/ batch | LOSS: 0.8270 |
# ...
